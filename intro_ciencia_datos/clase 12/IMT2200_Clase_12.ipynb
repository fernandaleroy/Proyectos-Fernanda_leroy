# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Profesor:** Rodrigo A. Carrasco <br>
# ---

# %% [markdown]
# # <h1><center>Clase 12: Transformación de Datos</center></h1>
#
# Este notebook continua el trabajo anterior, con el objetivo que los estudiantes del curso aprendan diferentes comandos y técnicas en Python y, en particular, en Pandas y con strings, para la transformación de datos.

# %% [markdown]
# ## 1. Imputación de datos faltantes
#
# Usaremos un set artificial (sintético) de datos para trabajar en imputación de datos faltantes.

# %%
# lectura de datos
import numpy as np
import pandas as pd

df = pd.read_csv('data\ejemplo_imp.csv')
df
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\rodri\AppData\Local\Temp\ipykernel_22020\1224778060.py:5: SyntaxWarning: invalid escape sequence '\e'
#   df = pd.read_csv('data\ejemplo_imp.csv')
#    col1 col2  col3   col4
# 0   100    a          5.4
# 1   200    b   5.6    NaN
# 2   300    c  10.5  100.4
# 3   400  NaN  12.2   30.2
# 4   500    e   NaN   40.5
# 5   600    f     *   40.5
# 6   700    g  45.7 -999.0

# %% [markdown]
# Identificación de datos faltantes

# %%
df.isna()
# Out:
#     col1   col2   col3   col4
# 0  False  False  False  False
# 1  False  False  False   True
# 2  False  False  False  False
# 3  False   True  False  False
# 4  False  False   True  False
# 5  False  False  False  False
# 6  False  False  False  False

# %% [markdown]
# Las funciones de `pandas` no permiten identificar en forma automática todo tipo de datos faltantes o erróneos.

# %%
df = df.replace('*', np.nan)
df = df.replace('None', np.nan)
df = df.replace(' ', np.nan)
df = df.replace(-999, np.nan)

# %%
df
# Out:
#    col1 col2  col3   col4
# 0   100    a   NaN    5.4
# 1   200    b   5.6    NaN
# 2   300    c  10.5  100.4
# 3   400  NaN  12.2   30.2
# 4   500    e   NaN   40.5
# 5   600    f   NaN   40.5
# 6   700    g  45.7    NaN

# %%
df.isna()
# Out:
#     col1   col2   col3   col4
# 0  False  False   True  False
# 1  False  False  False   True
# 2  False  False  False  False
# 3  False   True  False  False
# 4  False  False   True  False
# 5  False  False   True  False
# 6  False  False  False   True

# %% [markdown]
# Ahora que hemos identificado correctamente los datos faltantes, podemos definir qué hacer sobre los datos que faltan.

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3', 'col4'], dtype='object')

# %%
df.dropna(subset=['col2'])
# Out:
#    col1 col2  col3   col4
# 0   100    a   NaN    5.4
# 1   200    b   5.6    NaN
# 2   300    c  10.5  100.4
# 4   500    e   NaN   40.5
# 5   600    f   NaN   40.5
# 6   700    g  45.7    NaN

# %% [markdown]
# Importante: recuerden que este método no elimina los datos en el DataFrame original y debemos asignarlo para que ello ocurra.

# %%
df
# Out:
#    col1 col2  col3   col4
# 0   100    a   NaN    5.4
# 1   200    b   5.6    NaN
# 2   300    c  10.5  100.4
# 3   400  NaN  12.2   30.2
# 4   500    e   NaN   40.5
# 5   600    f   NaN   40.5
# 6   700    g  45.7    NaN

# %% [markdown]
# Hagamos ahora una imputación de valores faltantes.

# %%
df2 = df.copy()
df2
# Out:
#    col1 col2  col3   col4
# 0   100    a   NaN    5.4
# 1   200    b   5.6    NaN
# 2   300    c  10.5  100.4
# 3   400  NaN  12.2   30.2
# 4   500    e   NaN   40.5
# 5   600    f   NaN   40.5
# 6   700    g  45.7    NaN

# %%
df2['col2'] = df2['col2'].fillna(value='d')
df2
# Out:
#    col1 col2  col3   col4
# 0   100    a   NaN    5.4
# 1   200    b   5.6    NaN
# 2   300    c  10.5  100.4
# 3   400    d  12.2   30.2
# 4   500    e   NaN   40.5
# 5   600    f   NaN   40.5
# 6   700    g  45.7    NaN

# %% [markdown]
# ## 2 Limpieza de textos (strings)
#
# La limpieza no sólo puede ocurrir a nivel de columnas o filas, también puede que necesitemos limpiar texto para poder procesarlo posteriormente.

# %%
import requests
from bs4 import BeautifulSoup as bs

url = "https://en.wikipedia.org/wiki/2023_Rugby_World_Cup_squads"
headers = {"User-Agent": "imt2200-class-notebook"}
page = requests.get(url, headers=headers, timeout=10).text
soup = bs(page)
tables = soup.find_all('table')
# procesar la tabla 20 que tiene la escuadra de Chile
table = tables[19]

# %%
#creamos un DataFrame vacío con los títulos de la tabla
df = pd.DataFrame(columns = ['jugador','posicion','nacimiento','caps', 'club'])

# iterar sobre cada fila ('tr') para completar la información
for row in table.find_all('tr')[1::]:
    cols = row.find_all("td")
    #print(cols)
    cols = [col.text.strip() for col in cols]
    #print(cols)
    jugador = cols[0]
    posicion = cols[1]
    nacimiento = cols[2]
    caps = cols[3]
    club = cols[4]
    new_row = pd.DataFrame({'jugador': jugador, 'posicion': posicion, 'nacimiento': nacimiento,'caps':caps, 'club':club}, index=['jugador'])
    df = pd.concat([df, new_row], ignore_index=True)
df
# Out:
#                      jugador    posicion  \
# 0              Augusto Böhme      Hooker
# 1          Tomás Dussaillant      Hooker
# 2              Diego Escobar      Hooker
# 3            Javier Carrasco        Prop
# 4              Matías Dittus        Prop
# 5           Iñaki Gurruchaga        Prop
# 6          Esteban Inostroza        Prop
# 7            Vittorio Lastra        Prop
# 8              Salvador Lues        Prop
# 9             Javier Eissman        Lock
# 10               Pablo Huete        Lock
# 11          Santiago Pedrero        Lock
# 12         Augusto Sarmiento        Lock
# 13           Alfonso Escobar    Back row
# 14         Raimundo Martínez    Back row
# 15            Thomas Orchard    Back row
# 16         Clemente Saavedra    Back row
# 17         Martín Sigren (c)    Back row
# 18             Ignacio Silva    Back row
# 19            Lukas Carvallo  Scrum-half
# 20          Nicolás Herreros  Scrum-half
# 21         Marcelo Torrealba  Scrum-half
# 22           Benjamín Videla  Scrum-half
# 23         Rodrigo Fernández    Fly-half
# 24           Santiago Videla    Fly-half
# 25               Pablo Casas      Centre
# 26          Matías Garafulic      Centre
# 27      José Ignacio Larenas      Centre
# 28          Domingo Saavedra      Centre
# 29  Cristóbal Game Jiménez 1        Wing
# 30       Nicolás Garafulic 1        Wing
# 31            Franco Velarde        Wing
# 32              Iñaki Ayarza    Fullback
# 33           Francisco Urroz    Fullback
#
#                                  nacimiento caps               club
# 0        (1997-06-11)11 June 1997 (aged 26)   22            Selknam
# 1      (1990-10-06)6 October 1990 (aged 32)   37            Selknam
# 2       (2000-04-17)17 April 2000 (aged 23)    5            Selknam
# 3      (1997-08-24)24 August 1997 (aged 26)   19            Selknam
# 4        (1993-07-16)16 July 1993 (aged 30)   21          Périgueux
# 5     (1995-10-13)13 October 1995 (aged 27)   11            Selknam
# 6      (1994-01-01)1 January 1994 (aged 29)    1            Selknam
# 7       (1996-03-26)26 March 1996 (aged 27)   22            Selknam
# 8     (1999-11-06)6 November 1999 (aged 23)   11            Selknam
# 9       (1997-03-21)21 March 1997 (aged 26)   21            Selknam
# 10    (1989-01-11)11 January 1989 (aged 34)   30            Selknam
# 11   (2000-11-30)30 November 2000 (aged 22)    6            Selknam
# 12      (1993-04-30)30 April 1993 (aged 30)   15               PWCC
# 13     (1997-08-17)17 August 1997 (aged 26)   18            Selknam
# 14   (1999-11-25)25 November 1999 (aged 23)   10            Selknam
# 15    (1997-01-12)12 January 1997 (aged 26)   12            Selknam
# 16   (1997-12-15)15 December 1997 (aged 25)   20            Selknam
# 17        (1996-05-14)14 May 1996 (aged 27)   27  Doncaster Knights
# 18   (1989-02-16)16 February 1989 (aged 34)   38            Selknam
# 19        (2001-07-06)6 July 2001 (aged 22)    6            Selknam
# 20    (1990-01-23)23 January 1990 (aged 33)    5            Selknam
# 21         (1996-05-06)6 May 1996 (aged 27)   12            Selknam
# 22      (2001-04-24)24 April 2001 (aged 22)    0            Selknam
# 23    (1996-02-08)8 February 1996 (aged 27)   23            Selknam
# 24    (1998-01-16)16 January 1998 (aged 25)   25            Selknam
# 25       (1992-03-04)4 March 1992 (aged 31)   15            Selknam
# 26   (2000-09-01)1 September 2000 (aged 23)   12            Selknam
# 27  (1989-09-14)14 September 1989 (aged 33)   47            Selknam
# 28   (1997-12-15)15 December 1997 (aged 25)   24            Selknam
# 29        (2002-07-09)9 July 2002 (aged 21)    1         Old John's
# 30  (1998-09-11)11 September 1998 (aged 24)   19            Selknam
# 31    (1994-11-04)4 November 1994 (aged 28)   16              VOBGS
# 32   (1999-09-07)7 September 1999 (aged 24)   14   Soyaux Angoulême
# 33   (1993-09-07)7 September 1993 (aged 30)   11            Selknam

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   jugador     34 non-null     object
#  1   posicion    34 non-null     object
#  2   nacimiento  34 non-null     object
#  3   caps        34 non-null     object
#  4   club        34 non-null     object
# dtypes: object(5)
# memory usage: 1.5+ KB

# %%
df['caps'] = df['caps'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   jugador     34 non-null     object
#  1   posicion    34 non-null     object
#  2   nacimiento  34 non-null     object
#  3   caps        34 non-null     int32
#  4   club        34 non-null     object
# dtypes: int32(1), object(4)
# memory usage: 1.3+ KB

# %%
mean_caps = df['caps'].mean()
mean_caps
# Out:
# 16.941176470588236

# %%
df['caps'].describe()
# Out:
# count    34.000000
# mean     16.941176
# std      10.787033
# min       0.000000
# 25%      11.000000
# 50%      15.500000
# 75%      22.000000
# max      47.000000
# Name: caps, dtype: float64

# %%
df['edad'] = df['nacimiento'].str.slice(-3,-1)
df['edad'] = df['edad'].astype('int')

# %%
df.head()
# Out:
#              jugador posicion                            nacimiento  caps  \
# 0      Augusto Böhme   Hooker    (1997-06-11)11 June 1997 (aged 26)    22
# 1  Tomás Dussaillant   Hooker  (1990-10-06)6 October 1990 (aged 32)    37
# 2      Diego Escobar   Hooker   (2000-04-17)17 April 2000 (aged 23)     5
# 3    Javier Carrasco     Prop  (1997-08-24)24 August 1997 (aged 26)    19
# 4      Matías Dittus     Prop    (1993-07-16)16 July 1993 (aged 30)    21
#
#         club  edad
# 0    Selknam    26
# 1    Selknam    32
# 2    Selknam    23
# 3    Selknam    26
# 4  Périgueux    30

# %%
df['nacimiento'] = df['nacimiento'].str.slice(1,11)
df.head()
# Out:
#              jugador posicion  nacimiento  caps       club  edad
# 0      Augusto Böhme   Hooker  1997-06-11    22    Selknam    26
# 1  Tomás Dussaillant   Hooker  1990-10-06    37    Selknam    32
# 2      Diego Escobar   Hooker  2000-04-17     5    Selknam    23
# 3    Javier Carrasco     Prop  1997-08-24    19    Selknam    26
# 4      Matías Dittus     Prop  1993-07-16    21  Périgueux    30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   jugador     34 non-null     object
#  1   posicion    34 non-null     object
#  2   nacimiento  34 non-null     object
#  3   caps        34 non-null     int32
#  4   club        34 non-null     object
#  5   edad        34 non-null     int32
# dtypes: int32(2), object(4)
# memory usage: 1.5+ KB

# %% [markdown]
# ## 3 Variables categóricas
#
# La posición de los jugadores corresponde a una variable categórica pues sólo puede tomar un conjunto de valores predeterminados. Supongamos que para nuestro análisis queremos dividir a los jugadores sólo entre `forwards` y `backs`.

# %%
# Ver valores unicos presentes en el dataset
categorias = df['posicion'].unique()
categorias
# Out:
# array(['Hooker', 'Prop', 'Lock', 'Back row', 'Scrum-half', 'Fly-half',
#        'Centre', 'Wing', 'Fullback'], dtype=object)

# %%
# Definir lista de categorías que queremos
cat_simple = ['forwards','backs']

# Cuántos registros están en la lista de categorías deseadas?
df['posicion'].isin(cat_simple).sum()
# Out:
# 0

# %%
# Mapeo de categorías originales a nuevas categorías
map_cats={'Hooker':'forwards',
          'Prop':'forwards',
          'Lock':'forwards',
          'Back row':'forwards',
          'Scrum-half':'backs',
          'Fly-half':'backs',
          'Centre':'backs',
          'Wing':'backs',
          'Fullback':'backs'}
df['posicion_simple'] = df['posicion'].map(map_cats)

# %%
df
# Out:
#                      jugador    posicion  nacimiento  caps               club  \
# 0              Augusto Böhme      Hooker  1997-06-11    22            Selknam
# 1          Tomás Dussaillant      Hooker  1990-10-06    37            Selknam
# 2              Diego Escobar      Hooker  2000-04-17     5            Selknam
# 3            Javier Carrasco        Prop  1997-08-24    19            Selknam
# 4              Matías Dittus        Prop  1993-07-16    21          Périgueux
# 5           Iñaki Gurruchaga        Prop  1995-10-13    11            Selknam
# 6          Esteban Inostroza        Prop  1994-01-01     1            Selknam
# 7            Vittorio Lastra        Prop  1996-03-26    22            Selknam
# 8              Salvador Lues        Prop  1999-11-06    11            Selknam
# 9             Javier Eissman        Lock  1997-03-21    21            Selknam
# 10               Pablo Huete        Lock  1989-01-11    30            Selknam
# 11          Santiago Pedrero        Lock  2000-11-30     6            Selknam
# 12         Augusto Sarmiento        Lock  1993-04-30    15               PWCC
# 13           Alfonso Escobar    Back row  1997-08-17    18            Selknam
# 14         Raimundo Martínez    Back row  1999-11-25    10            Selknam
# 15            Thomas Orchard    Back row  1997-01-12    12            Selknam
# 16         Clemente Saavedra    Back row  1997-12-15    20            Selknam
# 17         Martín Sigren (c)    Back row  1996-05-14    27  Doncaster Knights
# 18             Ignacio Silva    Back row  1989-02-16    38            Selknam
# 19            Lukas Carvallo  Scrum-half  2001-07-06     6            Selknam
# 20          Nicolás Herreros  Scrum-half  1990-01-23     5            Selknam
# 21         Marcelo Torrealba  Scrum-half  1996-05-06    12            Selknam
# 22           Benjamín Videla  Scrum-half  2001-04-24     0            Selknam
# 23         Rodrigo Fernández    Fly-half  1996-02-08    23            Selknam
# 24           Santiago Videla    Fly-half  1998-01-16    25            Selknam
# 25               Pablo Casas      Centre  1992-03-04    15            Selknam
# 26          Matías Garafulic      Centre  2000-09-01    12            Selknam
# 27      José Ignacio Larenas      Centre  1989-09-14    47            Selknam
# 28          Domingo Saavedra      Centre  1997-12-15    24            Selknam
# 29  Cristóbal Game Jiménez 1        Wing  2002-07-09     1         Old John's
# 30       Nicolás Garafulic 1        Wing  1998-09-11    19            Selknam
# 31            Franco Velarde        Wing  1994-11-04    16              VOBGS
# 32              Iñaki Ayarza    Fullback  1999-09-07    14   Soyaux Angoulême
# 33           Francisco Urroz    Fullback  1993-09-07    11            Selknam
#
#     edad posicion_simple
# 0     26        forwards
# 1     32        forwards
# 2     23        forwards
# 3     26        forwards
# 4     30        forwards
# 5     27        forwards
# 6     29        forwards
# 7     27        forwards
# 8     23        forwards
# 9     26        forwards
# 10    34        forwards
# 11    22        forwards
# 12    30        forwards
# 13    26        forwards
# 14    23        forwards
# 15    26        forwards
# 16    25        forwards
# 17    27        forwards
# 18    34        forwards
# 19    22           backs
# 20    33           backs
# 21    27           backs
# 22    22           backs
# 23    27           backs
# 24    25           backs
# 25    31           backs
# 26    23           backs
# 27    33           backs
# 28    25           backs
# 29    21           backs
# 30    24           backs
# 31    28           backs
# 32    24           backs
# 33    30           backs

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Desafío:</b> Los datos de nacimiento siguen siendo `object`, lo cual nos limita en lo que podemos hacer con eso.
#
# <b>Los tres primeros que envíen este notebook transformando el dato de `nacimiento` a un dato de tipo `datetime` y validen con eso que la columna edad está correcta, tendrá +0.1 en la Tarea 2.</b>
# </div>
