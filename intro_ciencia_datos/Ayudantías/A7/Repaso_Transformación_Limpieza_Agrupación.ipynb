# %% [markdown]
# # Mini-Repaso: Transformación, Limpieza y Agrupación en **pandas**
#
# **IMT2200 — Introducción a la Ciencia de Datos**
#
# **Ayudantía 7**

# %% [markdown]
# ## Objetivos
# - Reforzar **transformación** y **limpieza** de datos con `pandas` (sin imputación).
# - Practicar **agrupación** (`groupby` / `agg`) y **uniones** (`merge`, `concat`, `join`).

# %% [markdown]
# ## 0) Setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1) Dataset sintético para practicar
#
# El DF está diseñado para tocar **strings**, **fechas en múltiples formatos**, **listas** y **números con separadores**.

# %%
import pandas as pd

df = pd.DataFrame({ 
    "id": [" 01","03","02","004","02 "],
    "nombre_completo": ["cARLos  Muñoz","  MARÍA   lopez ","José   TORRES", None,"josé  torres "],
    "emails": ["c.munoz@uc.cl; carlos@gmail.com", "maria.lopez@uc.cl", "jtorres@mail.com; J.TORRES@UC.CL", "andrea@uc.cl", None],
    "fono": ["(+56)912345678", "9 8765 1234", "fono: 987654321", "123-456-789", "(+56) 9-2222-3333"],
    # columnas nuevas que requieren normalización
    "historial_pagos": [
        [{"fecha":"10/01/2024","monto":"CLP 5000"},{"fecha":"15/02/2024","monto":"CLP 15000"}],
        [{"fecha":"20/03/2024","monto":"CLP 8500"}],
        [],
        [{"fecha":"05/04/2024","monto":"CLP 17450"},{"fecha":"01/05/2024","monto":"CLP 3000"}],
        [{"fecha":"12/06/2024","monto":"CLP 12000"}]
    ],
    "direccion": [
        {"calle":"Av. Principal 123","comuna":"Antofagasta","region":"II"},
        {"calle":"Calle Falsa 456","comuna":"Viña del Mar","region":"V"},
        {"calle":"Los Pinos 789","comuna":"Puerto Montt","region":"X"},
        {"calle":"Av. Central 321","comuna":"La Florida","region":"RM"},
        {"calle":"Diagonal 654","comuna":"Maipú","region":"RM"}
    ]
})

df
# Out:
#     id   nombre_completo                            emails               fono  \
# 0   01     cARLos  Muñoz   c.munoz@uc.cl; carlos@gmail.com     (+56)912345678
# 1   03    MARÍA   lopez                  maria.lopez@uc.cl        9 8765 1234
# 2   02     José   TORRES  jtorres@mail.com; J.TORRES@UC.CL    fono: 987654321
# 3  004              None                      andrea@uc.cl        123-456-789
# 4  02      josé  torres                               None  (+56) 9-2222-3333
#
#                                      historial_pagos  \
# 0  [{'fecha': '10/01/2024', 'monto': 'CLP 5000'},...
# 1     [{'fecha': '20/03/2024', 'monto': 'CLP 8500'}]
# 2                                                 []
# 3  [{'fecha': '05/04/2024', 'monto': 'CLP 17450'}...
# 4    [{'fecha': '12/06/2024', 'monto': 'CLP 12000'}]
#
#                                            direccion
# 0  {'calle': 'Av. Principal 123', 'comuna': 'Anto...
# 1  {'calle': 'Calle Falsa 456', 'comuna': 'Viña d...
# 2  {'calle': 'Los Pinos 789', 'comuna': 'Puerto M...
# 3  {'calle': 'Av. Central 321', 'comuna': 'La Flo...
# 4  {'calle': 'Diagonal 654', 'comuna': 'Maipú', '...

# %% [markdown]
# ## 2) Limpieza (sin imputación)
#
# **Reglas:** quitar duplicados, eliminar/etiquetar nulos críticos, normalizar strings, descomprimir listas, estandarizar fechas, convertir tipos.

# %%
clean = df.copy()

# %%
# A) Aplanar `direccion` (dict -> columnas)
dir_norm = pd.json_normalize(clean["direccion"])
clean_cols = pd.concat(
    [clean.drop(columns=["direccion"]).reset_index(drop=True),
     dir_norm.reset_index(drop=True)],
    axis=1
)
clean_cols
# Out:
#     id   nombre_completo                            emails               fono  \
# 0   01     cARLos  Muñoz   c.munoz@uc.cl; carlos@gmail.com     (+56)912345678
# 1   03    MARÍA   lopez                  maria.lopez@uc.cl        9 8765 1234
# 2   02     José   TORRES  jtorres@mail.com; J.TORRES@UC.CL    fono: 987654321
# 3  004              None                      andrea@uc.cl        123-456-789
# 4  02      josé  torres                               None  (+56) 9-2222-3333
#
#                                      historial_pagos              calle  \
# 0  [{'fecha': '10/01/2024', 'monto': 'CLP 5000'},...  Av. Principal 123
# 1     [{'fecha': '20/03/2024', 'monto': 'CLP 8500'}]    Calle Falsa 456
# 2                                                 []      Los Pinos 789
# 3  [{'fecha': '05/04/2024', 'monto': 'CLP 17450'}...    Av. Central 321
# 4    [{'fecha': '12/06/2024', 'monto': 'CLP 12000'}]       Diagonal 654
#
#          comuna region
# 0   Antofagasta     II
# 1  Viña del Mar      V
# 2  Puerto Montt      X
# 3    La Florida     RM
# 4         Maipú     RM

# %%
# B) Aplanar `historial_pagos` (lista -> filas)
pagos_exploded = clean_cols.explode("historial_pagos", ignore_index=True)
pagos_exploded = pagos_exploded.dropna(subset=["historial_pagos"])  # elimina listas vacías

pagos_norm = pd.json_normalize(pagos_exploded["historial_pagos"])
clean = pd.concat(
    [pagos_exploded.drop(columns=["historial_pagos"]).reset_index(drop=True),
     pagos_norm.reset_index(drop=True)],
    axis=1
)
clean
# Out:
#     id   nombre_completo                           emails               fono  \
# 0   01     cARLos  Muñoz  c.munoz@uc.cl; carlos@gmail.com     (+56)912345678
# 1   01     cARLos  Muñoz  c.munoz@uc.cl; carlos@gmail.com     (+56)912345678
# 2   03    MARÍA   lopez                 maria.lopez@uc.cl        9 8765 1234
# 3  004              None                     andrea@uc.cl        123-456-789
# 4  004              None                     andrea@uc.cl        123-456-789
# 5  02      josé  torres                              None  (+56) 9-2222-3333
#
#                calle        comuna region       fecha      monto
# 0  Av. Principal 123   Antofagasta     II  10/01/2024   CLP 5000
# 1  Av. Principal 123   Antofagasta     II  15/02/2024  CLP 15000
# 2    Calle Falsa 456  Viña del Mar      V  20/03/2024   CLP 8500
# 3    Av. Central 321    La Florida     RM  05/04/2024  CLP 17450
# 4    Av. Central 321    La Florida     RM  01/05/2024   CLP 3000
# 5       Diagonal 654         Maipú     RM  12/06/2024  CLP 12000

# %%
# 2.1 eliminar nulos críticos
clean = clean.dropna(subset=["nombre_completo"]).reset_index(drop=True)
clean
# Out:
#     id   nombre_completo                           emails               fono  \
# 0   01     cARLos  Muñoz  c.munoz@uc.cl; carlos@gmail.com     (+56)912345678
# 1   01     cARLos  Muñoz  c.munoz@uc.cl; carlos@gmail.com     (+56)912345678
# 2   03    MARÍA   lopez                 maria.lopez@uc.cl        9 8765 1234
# 3  02      josé  torres                              None  (+56) 9-2222-3333
#
#                calle        comuna region       fecha      monto
# 0  Av. Principal 123   Antofagasta     II  10/01/2024   CLP 5000
# 1  Av. Principal 123   Antofagasta     II  15/02/2024  CLP 15000
# 2    Calle Falsa 456  Viña del Mar      V  20/03/2024   CLP 8500
# 3       Diagonal 654         Maipú     RM  12/06/2024  CLP 12000

# %%
# 2.2 normalizar strings 
clean["nombre_completo"] = (clean["nombre_completo"]
    .str.strip()                      # elimina espacios al inicio y final
    .str.title()                      # pone en formato título (primera letra mayúscula)
    .str.replace(r"\s+", " ", regex=True) # reemplaza múltiples espacios por uno solo
)
# separar nombre/apellido 
clean[["nombre", "apellido"]] = clean["nombre_completo"].str.split(" ", n=1, expand=True) # Hace solo una separación # expand=True para que retorne un DataFrame
clean
# Out:
#     id nombre_completo                           emails               fono  \
# 0   01    Carlos Muñoz  c.munoz@uc.cl; carlos@gmail.com     (+56)912345678
# 1   01    Carlos Muñoz  c.munoz@uc.cl; carlos@gmail.com     (+56)912345678
# 2   03     María Lopez                maria.lopez@uc.cl        9 8765 1234
# 3  02      José Torres                             None  (+56) 9-2222-3333
#
#                calle        comuna region       fecha      monto  nombre  \
# 0  Av. Principal 123   Antofagasta     II  10/01/2024   CLP 5000  Carlos
# 1  Av. Principal 123   Antofagasta     II  15/02/2024  CLP 15000  Carlos
# 2    Calle Falsa 456  Viña del Mar      V  20/03/2024   CLP 8500   María
# 3       Diagonal 654         Maipú     RM  12/06/2024  CLP 12000    José
#
#   apellido
# 0    Muñoz
# 1    Muñoz
# 2    Lopez
# 3   Torres

# %%
# 2.3 normalizar emails -> lista y explode
clean["emails"] = clean["emails"].str.replace(" ", "", regex=False).str.lower() # eliminar espacios y pasar a minúscula
clean["emails_list"] = clean["emails"].str.split(";") # separar por ;
clean = clean.drop(columns=["emails"]).explode("emails_list", ignore_index=True).rename(columns={"emails_list":"email"}) # explotar lista de emails
clean
# Out:
#     id nombre_completo               fono              calle        comuna  \
# 0   01    Carlos Muñoz     (+56)912345678  Av. Principal 123   Antofagasta
# 1   01    Carlos Muñoz     (+56)912345678  Av. Principal 123   Antofagasta
# 2   01    Carlos Muñoz     (+56)912345678  Av. Principal 123   Antofagasta
# 3   01    Carlos Muñoz     (+56)912345678  Av. Principal 123   Antofagasta
# 4   03     María Lopez        9 8765 1234    Calle Falsa 456  Viña del Mar
# 5  02      José Torres  (+56) 9-2222-3333       Diagonal 654         Maipú
#
#   region       fecha      monto  nombre apellido              email
# 0     II  10/01/2024   CLP 5000  Carlos    Muñoz      c.munoz@uc.cl
# 1     II  10/01/2024   CLP 5000  Carlos    Muñoz   carlos@gmail.com
# 2     II  15/02/2024  CLP 15000  Carlos    Muñoz      c.munoz@uc.cl
# 3     II  15/02/2024  CLP 15000  Carlos    Muñoz   carlos@gmail.com
# 4      V  20/03/2024   CLP 8500   María    Lopez  maria.lopez@uc.cl
# 5     RM  12/06/2024  CLP 12000    José   Torres               None

# %%
# 2.4 normalizar fono (dejar solo dígitos y remover prefijo 56)
clean["fono"] = (clean["fono"].astype(str)
                          .str.replace(r"\D+", "", regex=True) # dejar solo dígitos
                          .str.replace(r"^56", "", regex=True)) # remover prefijo 56
clean
# Out:
#     id nombre_completo       fono              calle        comuna region  \
# 0   01    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1   01    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2   01    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3   01    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   03     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
# 5  02      José Torres  922223333       Diagonal 654         Maipú     RM
#
#         fecha      monto  nombre apellido              email
# 0  10/01/2024   CLP 5000  Carlos    Muñoz      c.munoz@uc.cl
# 1  10/01/2024   CLP 5000  Carlos    Muñoz   carlos@gmail.com
# 2  15/02/2024  CLP 15000  Carlos    Muñoz      c.munoz@uc.cl
# 3  15/02/2024  CLP 15000  Carlos    Muñoz   carlos@gmail.com
# 4  20/03/2024   CLP 8500   María    Lopez  maria.lopez@uc.cl
# 5  12/06/2024  CLP 12000    José   Torres               None

# %%
# 2.5 normalizar id → Int64 (permite NA)
clean["id"] = (clean["id"].str.strip().astype("Int64"))
clean
# Out:
#    id nombre_completo       fono              calle        comuna region  \
# 0   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
# 5   2     José Torres  922223333       Diagonal 654         Maipú     RM
#
#         fecha      monto  nombre apellido              email
# 0  10/01/2024   CLP 5000  Carlos    Muñoz      c.munoz@uc.cl
# 1  10/01/2024   CLP 5000  Carlos    Muñoz   carlos@gmail.com
# 2  15/02/2024  CLP 15000  Carlos    Muñoz      c.munoz@uc.cl
# 3  15/02/2024  CLP 15000  Carlos    Muñoz   carlos@gmail.com
# 4  20/03/2024   CLP 8500   María    Lopez  maria.lopez@uc.cl
# 5  12/06/2024  CLP 12000    José   Torres               None

# %%
# Normalizar fechas con formato "%d/%m/%Y"
clean["fecha"] = pd.to_datetime(clean["fecha"], format="%d/%m/%Y", errors="coerce")
clean
# Out:
#    id nombre_completo       fono              calle        comuna region  \
# 0   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
# 5   2     José Torres  922223333       Diagonal 654         Maipú     RM
#
#        fecha      monto  nombre apellido              email
# 0 2024-01-10   CLP 5000  Carlos    Muñoz      c.munoz@uc.cl
# 1 2024-01-10   CLP 5000  Carlos    Muñoz   carlos@gmail.com
# 2 2024-02-15  CLP 15000  Carlos    Muñoz      c.munoz@uc.cl
# 3 2024-02-15  CLP 15000  Carlos    Muñoz   carlos@gmail.com
# 4 2024-03-20   CLP 8500   María    Lopez  maria.lopez@uc.cl
# 5 2024-06-12  CLP 12000    José   Torres               None

# %%
# Normalizar montos (remover "CLP " y ".")
clean["monto"] = (clean["monto"].str.replace("CLP ", "", regex=False)
                          .str.replace(".", "", regex=False)
                          .str.replace(",", "", regex=False)
                          .replace("", None)
                          .astype("Int64"))
clean
# Out:
#    id nombre_completo       fono              calle        comuna region  \
# 0   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
# 5   2     José Torres  922223333       Diagonal 654         Maipú     RM
#
#        fecha  monto  nombre apellido              email
# 0 2024-01-10   5000  Carlos    Muñoz      c.munoz@uc.cl
# 1 2024-01-10   5000  Carlos    Muñoz   carlos@gmail.com
# 2 2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl
# 3 2024-02-15  15000  Carlos    Muñoz   carlos@gmail.com
# 4 2024-03-20   8500   María    Lopez  maria.lopez@uc.cl
# 5 2024-06-12  12000    José   Torres               None

# %% [markdown]
# ## 3) `merge` y **cardinalidad**

# %%
clean
# Out:
#    id nombre_completo       fono              calle        comuna region  \
# 0   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
# 5   2     José Torres  922223333       Diagonal 654         Maipú     RM
#
#        fecha  monto  nombre apellido              email
# 0 2024-01-10   5000  Carlos    Muñoz      c.munoz@uc.cl
# 1 2024-01-10   5000  Carlos    Muñoz   carlos@gmail.com
# 2 2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl
# 3 2024-02-15  15000  Carlos    Muñoz   carlos@gmail.com
# 4 2024-03-20   8500   María    Lopez  maria.lopez@uc.cl
# 5 2024-06-12  12000    José   Torres               None

# %%
# DF de perfil por id (1-1)
perfil = pd.DataFrame({
    "id": [1,2,3],
    "es_titular": [True, False, True]
})

# DF de pagos (1-N respecto a id)
pagos = pd.DataFrame({
    "id": [1,1,2,3,3,3],
    "fecha_pago": pd.to_datetime(["2024-03-15","2024-04-01","2024-04-20","2024-05-12","2024-05-31","2024-06-10"]),
    "monto_pagado": [5000, 5000, 12500, 1500, 3000, 0]
})

display(perfil)
display(pagos)
# Out:
#    id  es_titular
# 0   1        True
# 1   2       False
# 2   3        True
#    id fecha_pago  monto_pagado
# 0   1 2024-03-15          5000
# 1   1 2024-04-01          5000
# 2   2 2024-04-20         12500
# 3   3 2024-05-12          1500
# 4   3 2024-05-31          3000
# 5   3 2024-06-10             0

# %%
# Imprimir solo el dia y mes
dia_mes = perfil.merge(pagos, on="id", how="left")
dia_mes["año"] = dia_mes["fecha_pago"].dt.year
dia_mes["dia_mes"]= dia_mes["fecha_pago"].dt.strftime("%d-%m")
dia_mes
# Out:
#    id  es_titular fecha_pago  monto_pagado   año dia_mes
# 0   1        True 2024-03-15          5000  2024   15-03
# 1   1        True 2024-04-01          5000  2024   01-04
# 2   2       False 2024-04-20         12500  2024   20-04
# 3   3        True 2024-05-12          1500  2024   12-05
# 4   3        True 2024-05-31          3000  2024   31-05
# 5   3        True 2024-06-10             0  2024   10-06

# %%
clean
# Out:
#    id nombre_completo       fono              calle        comuna region  \
# 0   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
# 5   2     José Torres  922223333       Diagonal 654         Maipú     RM
#
#        fecha  monto  nombre apellido              email
# 0 2024-01-10   5000  Carlos    Muñoz      c.munoz@uc.cl
# 1 2024-01-10   5000  Carlos    Muñoz   carlos@gmail.com
# 2 2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl
# 3 2024-02-15  15000  Carlos    Muñoz   carlos@gmail.com
# 4 2024-03-20   8500   María    Lopez  maria.lopez@uc.cl
# 5 2024-06-12  12000    José   Torres               None

# %%
# 3.1 Inner/Left/Right/Outer
m_inner = pd.merge(clean, perfil, on="id", how="inner")
m_left  = pd.merge(clean, perfil, on="id", how="left")
m_outer = pd.merge(clean, perfil, on="id", how="outer")

display(m_inner.head())
display(m_left.head())
display(m_outer.tail())
# Out:
#    id nombre_completo       fono              calle        comuna region  \
# 0   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
#
#        fecha  monto  nombre apellido              email  es_titular
# 0 2024-01-10   5000  Carlos    Muñoz      c.munoz@uc.cl        True
# 1 2024-01-10   5000  Carlos    Muñoz   carlos@gmail.com        True
# 2 2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl        True
# 3 2024-02-15  15000  Carlos    Muñoz   carlos@gmail.com        True
# 4 2024-03-20   8500   María    Lopez  maria.lopez@uc.cl        True
#    id nombre_completo       fono              calle        comuna region  \
# 0   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
#
#        fecha  monto  nombre apellido              email  es_titular
# 0 2024-01-10   5000  Carlos    Muñoz      c.munoz@uc.cl        True
# 1 2024-01-10   5000  Carlos    Muñoz   carlos@gmail.com        True
# 2 2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl        True
# 3 2024-02-15  15000  Carlos    Muñoz   carlos@gmail.com        True
# 4 2024-03-20   8500   María    Lopez  maria.lopez@uc.cl        True
#    id nombre_completo       fono              calle        comuna region  \
# 1   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   2     José Torres  922223333       Diagonal 654         Maipú     RM
# 5   3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
#
#        fecha  monto  nombre apellido              email  es_titular
# 1 2024-01-10   5000  Carlos    Muñoz   carlos@gmail.com        True
# 2 2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl        True
# 3 2024-02-15  15000  Carlos    Muñoz   carlos@gmail.com        True
# 4 2024-06-12  12000    José   Torres               None       False
# 5 2024-03-20   8500   María    Lopez  maria.lopez@uc.cl        True

# %%
# 3.2 1-N: cuidado con duplicados tras el merge
m_1N = pd.merge(clean, pagos, on="id", how="left")
print("Filas clean:", len(clean), "→ tras merge 1-N:", len(m_1N))
m_1N = m_1N.sort_values(["id", "fecha_pago"]).head(10)
m_1N
# Out:
# Filas clean: 6 → tras merge 1-N: 12
#     id nombre_completo       fono              calle        comuna region  \
# 0    1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 2    1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4    1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 6    1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1    1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 3    1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 5    1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 7    1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 11   2     José Torres  922223333       Diagonal 654         Maipú     RM
# 8    3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
#
#         fecha  monto  nombre apellido              email fecha_pago  \
# 0  2024-01-10   5000  Carlos    Muñoz      c.munoz@uc.cl 2024-03-15
# 2  2024-01-10   5000  Carlos    Muñoz   carlos@gmail.com 2024-03-15
# 4  2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl 2024-03-15
# 6  2024-02-15  15000  Carlos    Muñoz   carlos@gmail.com 2024-03-15
# 1  2024-01-10   5000  Carlos    Muñoz      c.munoz@uc.cl 2024-04-01
# 3  2024-01-10   5000  Carlos    Muñoz   carlos@gmail.com 2024-04-01
# 5  2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl 2024-04-01
# 7  2024-02-15  15000  Carlos    Muñoz   carlos@gmail.com 2024-04-01
# 11 2024-06-12  12000    José   Torres               None 2024-04-20
# 8  2024-03-20   8500   María    Lopez  maria.lopez@uc.cl 2024-05-12
#
#     monto_pagado
# 0           5000
# 2           5000
# 4           5000
# 6           5000
# 1           5000
# 3           5000
# 5           5000
# 7           5000
# 11         12500
# 8           1500

# %% [markdown]
# ## 4) Agrupación (`groupby`/`agg`/`apply`)
#
# Estadísticas por **id**, **región** y combinaciones.

# %%
# 4.1 agregaciones básicas
g1 = m_1N.groupby("id").agg(
    n_emails=("email","nunique"),
    n_pagos=("fecha_pago","count"),
    monto_total=("monto_pagado","sum"),
    monto_promedio=("monto_pagado","mean")
).reset_index()

g1
# Out:
#    id  n_emails  n_pagos  monto_total  monto_promedio
# 0   1         2        8        40000          5000.0
# 1   2         0        1        12500         12500.0
# 2   3         1        1         1500          1500.0

# %%
# 4.2 multi-col y funciones diferentes
g2 = (m_1N.groupby(["nombre_completo"]).agg(ingresos=("monto","sum"), 
                                            primera_atencion=("fecha","min"),
                                            ult_pago=("fecha_pago","max"),
                                            egresos = ("monto_pagado","sum")).reset_index())
g2
# Out:
#   nombre_completo  ingresos primera_atencion   ult_pago  egresos
# 0    Carlos Muñoz     80000       2024-01-10 2024-04-01    40000
# 1     José Torres     12000       2024-06-12 2024-04-20    12500
# 2     María Lopez      8500       2024-03-20 2024-05-12     1500

# %%
g2["diferencia"] = g2["ingresos"] - g2["egresos"]
g2
# Out:
#   nombre_completo  ingresos primera_atencion   ult_pago  egresos  diferencia
# 0    Carlos Muñoz     80000       2024-01-10 2024-04-01    40000       40000
# 1     José Torres     12000       2024-06-12 2024-04-20    12500        -500
# 2     María Lopez      8500       2024-03-20 2024-05-12     1500        7000

# %%
# 4.3 apply para encontrar todos los correos uc
def es_uc(email):
    return email.endswith("@uc.cl") if isinstance(email, str) else False

m_1N["es_uc"] = m_1N["email"].apply(es_uc)
m_1N[m_1N["es_uc"]]
# Out:
#    id nombre_completo       fono              calle        comuna region  \
# 0   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 4   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 1   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 5   1    Carlos Muñoz  912345678  Av. Principal 123   Antofagasta     II
# 8   3     María Lopez  987651234    Calle Falsa 456  Viña del Mar      V
#
#        fecha  monto  nombre apellido              email fecha_pago  \
# 0 2024-01-10   5000  Carlos    Muñoz      c.munoz@uc.cl 2024-03-15
# 4 2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl 2024-03-15
# 1 2024-01-10   5000  Carlos    Muñoz      c.munoz@uc.cl 2024-04-01
# 5 2024-02-15  15000  Carlos    Muñoz      c.munoz@uc.cl 2024-04-01
# 8 2024-03-20   8500   María    Lopez  maria.lopez@uc.cl 2024-05-12
#
#    monto_pagado  es_uc
# 0          5000   True
# 4          5000   True
# 1          5000   True
# 5          5000   True
# 8          1500   True
